# %% [markdown]
# # Classificando cães 🐕 e gatos 🐈
#
# Você já imaginou criar uma rede neural para classificar imagens? As redes neurais convolucionais (CNNs) são amplamente utilizadas em uma variedade de aplicações de visão computacional e processamento de imagens devido à sua capacidade de aprender representações hierárquicas de dados.
#
# Na aula de hoje vamos criar uma rede neural para classificar cães e gatos. Sabemos que para os olhos humanos é fácil a identificação dos animais por meio de algumas diferenças entre ambos, tal como gatos possuem os olhos mais puxadinhos, orelhinhas mais pontudas e entre outras características. Mas também sabemos que temos cães que podem ter características semelhantes ao gato, tal como a orelhinha pontuda, cauda longa, e entre outras características. Será que a rede neural consegue distinguir os animais? Vamos codar e descobrir juntos!!

# %% [markdown]
# ## Sobre a base de dados
#
# Essa base de dados está disponível no Kaggle, lá é possível encontrar diversas bases para trabalhar com dados de visão computacional! Para nossa aula de hoje, selecionei essa base de gatinhos e cachorrinhos fofos!
#
# Link: https://www.kaggle.com/datasets/moazeldsokyx/dogs-vs-cats

# %% [markdown]
# ## Importando as bibliotecas que vamos utilizar na aula de hoje:

# %%
# Blibliotecas essenciais
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import os
import cv2

# Para Deep Learning
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense, Dropout, Conv2D, BatchNormalization
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam

# Para validação do modelo
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
# Montando ambiente do google

from google.colab import drive
drive.mount('/content/drive')

import os
caminho_da_pasta = "/content/drive/My Drive/cat_dog_images"
pasta_imagens = Path(caminho_da_pasta)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Depois de importar as bibliotecas necessárias para realizar nosso projeto, vamos utilizar o glob para listar as imagens que possuem o padrão ".jpg" (que no caso são imagens de cachorrinhos e gatinhos que estão aqui na pasta do drive).

# %%
# Listando toas as imagens do diretório
filepaths = list(pasta_imagens.glob(r'**/*.jpg'))
filepaths
# Out:
# [PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.0.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.105.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.102.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.1.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.103.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.100.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.106.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.1000.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.104.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.101.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.112.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.114.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.113.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.115.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.111.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.117.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.109.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.116.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.14.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.152.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.119.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.150.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.140.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.134.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.136.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.118.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.156.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.12.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.125.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.13.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.126.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.128.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.132.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.155.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.151.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.123.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.124.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.139.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.120.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.141.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.149.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.146.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.131.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.147.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.129.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.121.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.15.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.142.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.130.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.153.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.122.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.144.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.127.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.138.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.135.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.154.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.145.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.133.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.17.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.194.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.171.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.18.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.209.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.238.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.206.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.221.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.254.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.184.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.229.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.243.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.176.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.237.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.212.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.228.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.22.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.185.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.215.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.205.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.159.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.245.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.168.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.232.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.226.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.167.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.170.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.217.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.199.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.190.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.201.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.24.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.188.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.210.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.242.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.227.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.200.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.231.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.214.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.219.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.252.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.248.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.234.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.213.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.230.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.223.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.19.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.220.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.253.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.257.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.158.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.20.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.187.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.240.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.166.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.21.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.208.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.246.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.249.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.189.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.198.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.182.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.177.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.161.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.244.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.183.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.165.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.164.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.251.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.241.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.173.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.163.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.16.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.157.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.160.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.225.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.192.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.218.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.179.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.172.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.222.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.239.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.193.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.211.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.256.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.247.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.191.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.197.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.196.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.216.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.180.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.181.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.23.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.178.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.316.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.318.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.332.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.285.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.3.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.333.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.357.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.299.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.34.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.291.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.268.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.319.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.336.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.350.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.293.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.343.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.338.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.259.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.345.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.342.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.283.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.354.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.320.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.322.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.296.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.273.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.337.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.309.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.29.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.346.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.331.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.276.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.278.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.358.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.30.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.326.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.347.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.274.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.325.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.311.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.323.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.312.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.284.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.287.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.295.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.313.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.335.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.329.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.307.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.300.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.277.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.28.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.314.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.327.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.281.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.282.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.280.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.260.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.269.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.359.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.264.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.31.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.349.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.310.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.341.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.272.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.356.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.266.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.261.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.32.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.289.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.355.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.330.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.265.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.33.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.303.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.339.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.26.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.288.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.353.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.286.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.304.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.305.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.302.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.262.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.324.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.267.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.270.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.292.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.420.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.411.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.46.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.403.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.391.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.380.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.429.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.460.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.449.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.421.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.361.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.440.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.445.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.415.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.360.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.444.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.431.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.402.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.418.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.423.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.458.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.455.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.377.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.375.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.368.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.364.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.452.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.456.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.43.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.41.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.379.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.443.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.40.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.422.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.392.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.367.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.427.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.389.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.382.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.371.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.439.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.412.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.438.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.363.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.416.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.384.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.365.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.407.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.413.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.4.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.462.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.376.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.414.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.428.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.417.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.397.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.38.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.388.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.408.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.425.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.441.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.378.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.394.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.426.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.450.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.36.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.442.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.369.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.459.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.406.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.387.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.419.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.461.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.457.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.430.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.448.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.362.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.45.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.385.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.381.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.464.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.434.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.400.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.374.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.383.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.453.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.398.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.424.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.437.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.395.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.446.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.454.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.405.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.504.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.549.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.493.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.558.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.557.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.538.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.543.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.517.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.542.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.487.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.532.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.465.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.524.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.513.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.54.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.505.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.525.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.509.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.541.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.467.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.47.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.473.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.511.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.539.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.52.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.534.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.49.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.476.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.471.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.535.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.519.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.56.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.469.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.530.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.5.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.548.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.479.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.507.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.518.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.50.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.536.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.523.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.472.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.474.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.553.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.484.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.529.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.495.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.533.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.470.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.556.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.51.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.502.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.561.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.53.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.527.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.528.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.55.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.540.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.496.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.489.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.520.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.500.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.499.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.555.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.468.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.48.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.508.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.521.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.547.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.546.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.550.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.483.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.531.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.559.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.512.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.482.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.503.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.488.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.492.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.506.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.514.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.494.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.562.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.560.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.480.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.551.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.497.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.641.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.615.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.611.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.642.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.599.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.637.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.639.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.598.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.610.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.635.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.572.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.614.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.651.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.656.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.630.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.606.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.577.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.619.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.587.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.638.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.646.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.640.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.57.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.653.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.607.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.594.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.632.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.633.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.649.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.597.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.65.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.586.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.595.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.565.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.60.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.628.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.585.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.571.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.590.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.568.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.582.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.601.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.600.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.657.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.603.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.644.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.584.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.575.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.64.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.622.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.588.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.652.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.645.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.624.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.625.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.647.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.629.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.566.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.583.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.636.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.62.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.63.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.648.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.620.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.604.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.578.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.626.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.654.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.580.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.592.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.613.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.569.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.631.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.574.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.616.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.573.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.602.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.59.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.650.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.570.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.627.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.591.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.612.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.6.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.567.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.609.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.576.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.623.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.74.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.735.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.683.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.685.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.712.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.742.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.720.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.721.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.72.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.718.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.687.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.746.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.748.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.693.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.673.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.667.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.67.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.68.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.736.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.709.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.706.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.697.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.662.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.732.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.733.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.659.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.668.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.675.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.750.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.684.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.71.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.689.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.695.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.728.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.714.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.741.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.679.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.680.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.727.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.738.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.66.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.705.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.664.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.737.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.747.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.731.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.669.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.696.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.688.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.743.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.671.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.702.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.723.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.70.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.715.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.676.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.726.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.719.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.674.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.69.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.729.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.73.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.744.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.739.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.666.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.749.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.700.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.692.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.690.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.694.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.722.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.670.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.672.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.730.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.686.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.711.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.717.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.704.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.708.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.707.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.724.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.772.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.778.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.774.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.806.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.814.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.824.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.816.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.788.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.805.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.808.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.838.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.800.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.766.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.785.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.82.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.798.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.796.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.819.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.763.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.792.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.761.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.757.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.8.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.807.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.827.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.841.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.764.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.842.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.782.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.769.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.751.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.846.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.762.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.784.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.753.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.78.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.837.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.813.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.787.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.773.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.818.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.830.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.801.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.835.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.820.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.812.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.765.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.810.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.80.jpg'),
# ...
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.987.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.974.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.995.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.975.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.993.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.985.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.966.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.991.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.98.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/gatinhos/cat.965.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.1000.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.101.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.103.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.10.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.102.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.1.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.0.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.111.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.107.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.113.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.110.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.109.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.114.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.11.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.112.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.123.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.12.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.122.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.120.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.121.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.116.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.124.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.119.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.117.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.168.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.132.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.135.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.213.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.200.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.128.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.125.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.157.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.172.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.188.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.199.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.159.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.151.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.203.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.21.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.13.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.186.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.185.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.211.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.166.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.147.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.142.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.144.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.206.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.207.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.197.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.179.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.18.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.153.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.130.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.161.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.158.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.217.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.156.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.154.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.155.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.167.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.204.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.205.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.2.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.201.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.131.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.170.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.174.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.141.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.178.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.160.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.180.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.140.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.209.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.190.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.215.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.218.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.126.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.194.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.212.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.173.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.219.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.162.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.19.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.145.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.192.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.177.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.202.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.164.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.175.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.16.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.134.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.138.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.182.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.150.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.17.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.183.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.136.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.149.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.163.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.184.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.133.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.195.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.198.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.169.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.196.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.148.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.137.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.187.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.165.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.191.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.193.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.143.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.171.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.267.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.272.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.261.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.273.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.244.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.289.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.293.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.236.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.246.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.228.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.294.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.220.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.245.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.297.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.255.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.23.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.280.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.298.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.235.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.223.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.275.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.226.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.259.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.252.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.282.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.24.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.276.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.230.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.250.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.253.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.247.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.241.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.256.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.249.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.248.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.237.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.299.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.271.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.26.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.260.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.277.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.296.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.270.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.231.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.258.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.242.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.232.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.221.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.278.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.25.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.28.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.240.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.224.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.265.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.290.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.285.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.287.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.268.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.263.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.234.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.22.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.229.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.286.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.233.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.227.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.254.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.239.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.283.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.284.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.281.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.243.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.326.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.380.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.358.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.301.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.395.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.364.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.371.jpg'),
#  PosixPath('/content/drive/My Drive/cat_dog_images/cachorrinhos/dog.324.jpg'),
#  ...]

# %% [markdown]
# ## Tratando os dados
#
# Como próximo passo, vamos armazenar as **targets** do nosso modelo e as **imagens** em uma **lista**. Para todas as imagens localizadas em filepaths, vamos percorrer com um **loop cada uma das imagens e realizar algumas tratativas** como por exemplo redimensionar a imagem e normalizar o intervalo de pixel para ficar entre 0 e 1 e armazena-la nas listas.
#
# Aqui é importante relembrar que redes neurais funcionam melhor quando estão com os dados normalizados ou padronizados.

# %%
# Iniciando rótulos e listas de imagens para armazenar os dados
labels = [] # armazenando as variáveis target
images = [] # armazenando imagens

# Definindo o tamanho da dimensão da imagem
image_size = 64

# Um loop for para definir as variáveis x e y para os modelos
for filepath in filepaths:
  # Divide o nome do caminho para extrair o cabeçalho do caminho com split
  head = os.path.split(filepath)
  # Divide o cabeçalho do caminho anterior para extrair o nome do animal
  animal = os.path.split(head[0])
  # Armazena o nome do animal na lista de labels
  labels.append(animal[1])
  # Obtem a imagem do caminho com cv2
  img = cv2.imread(str(filepath))
  # Redimensiona a imagem e normalize o intervalo de pixels para ficar entre 0 e 1(padronização)
  # Utilizando float32 para criar uma precisão limitada (menor demanda de memória em comparação com tipos de ponto flutuante de maior precisão: float64)
  img = cv2.resize(img, (image_size, image_size)).astype('float32') / 255.0
  # Adiciona a imagem na lista de imagens
  images.append(img)

# Converte a imagem em lista de array
images = np.array(images)
# Converte as labels para lista de array
labels = np.array(labels)

# %% [markdown]
# Muito bem! Agora temos as imagens armazenadas em um formato de um grande array na variável "images" e os rótulos em "labels".

# %%
images.shape
# Out:
# (1605, 64, 64, 3)

# %% [markdown]
# * 807 amostras (gatinhos e cachorrinhos)
# * 64x64 (dimensão)
# * 3 (número de matrizes que compõe a imagem (RGB))

# %%
images
# Out:
# array([[[[0.3529412 , 0.654902  , 0.80784315],
#          [0.3764706 , 0.6784314 , 0.83137256],
#          [0.39607844, 0.7019608 , 0.87058824],
#          ...,
#          [0.5411765 , 0.84313726, 0.972549  ],
#          [0.5019608 , 0.81960785, 0.96862745],
#          [0.47843137, 0.8       , 0.9529412 ]],
#
#         [[0.3529412 , 0.654902  , 0.80784315],
#          [0.3764706 , 0.6784314 , 0.83137256],
#          [0.39607844, 0.7019608 , 0.87058824],
#          ...,
#          [0.5568628 , 0.85490197, 0.96862745],
#          [0.5254902 , 0.83137256, 0.96862745],
#          [0.49411765, 0.80784315, 0.95686275]],
#
#         [[0.3529412 , 0.654902  , 0.80784315],
#          [0.3764706 , 0.6784314 , 0.83137256],
#          [0.39607844, 0.7019608 , 0.87058824],
#          ...,
#          [0.5686275 , 0.8509804 , 0.96862745],
#          [0.5529412 , 0.84705883, 0.96862745],
#          [0.5137255 , 0.81960785, 0.96862745]],
#
#         ...,
#
#         [[0.22352941, 0.5019608 , 0.63529414],
#          [0.23921569, 0.5176471 , 0.6509804 ],
#          [0.24705882, 0.5254902 , 0.67058825],
#          ...,
#          [0.        , 0.01568628, 0.01176471],
#          [0.        , 0.01568628, 0.01176471],
#          [0.        , 0.01176471, 0.00784314]],
#
#         [[0.21176471, 0.49019608, 0.627451  ],
#          [0.22352941, 0.5019608 , 0.63529414],
#          [0.23137255, 0.50980395, 0.654902  ],
#          ...,
#          [0.        , 0.01568628, 0.01176471],
#          [0.        , 0.01568628, 0.01176471],
#          [0.        , 0.01176471, 0.00784314]],
#
#         [[0.21960784, 0.48235294, 0.6039216 ],
#          [0.23529412, 0.5019608 , 0.61960787],
#          [0.22745098, 0.50980395, 0.6431373 ],
#          ...,
#          [0.        , 0.00784314, 0.00784314],
#          [0.        , 0.00784314, 0.00784314],
#          [0.        , 0.00784314, 0.00784314]]],
#
#
#        [[[0.32941177, 0.37254903, 0.40392157],
#          [0.40392157, 0.44705883, 0.47843137],
#          [0.4117647 , 0.45490196, 0.4862745 ],
#          ...,
#          [0.9647059 , 0.9647059 , 0.9647059 ],
#          [0.92941177, 0.9490196 , 0.94509804],
#          [0.9372549 , 0.95686275, 0.9529412 ]],
#
#         [[0.32941177, 0.37254903, 0.40392157],
#          [0.40392157, 0.44705883, 0.47843137],
#          [0.41568628, 0.45490196, 0.49019608],
#          ...,
#          [0.9529412 , 0.9529412 , 0.9529412 ],
#          [0.93333334, 0.9529412 , 0.9490196 ],
#          [0.9411765 , 0.9607843 , 0.95686275]],
#
#         [[0.32941177, 0.37254903, 0.40392157],
#          [0.40392157, 0.44705883, 0.47843137],
#          [0.41568628, 0.45882353, 0.49411765],
#          ...,
#          [0.9411765 , 0.9411765 , 0.9411765 ],
#          [0.9372549 , 0.95686275, 0.9529412 ],
#          [0.94509804, 0.9647059 , 0.9607843 ]],
#
#         ...,
#
#         [[0.03137255, 0.09803922, 0.21568628],
#          [0.01568628, 0.08235294, 0.20392157],
#          [0.        , 0.07058824, 0.1882353 ],
#          ...,
#          [0.10588235, 0.60784316, 0.7647059 ],
#          [0.19215687, 0.7137255 , 0.85882354],
#          [0.17254902, 0.73333335, 0.87058824]],
#
#         [[0.02352941, 0.11372549, 0.24313726],
#          [0.01568628, 0.11372549, 0.24705882],
#          [0.07843138, 0.1882353 , 0.32156864],
#          ...,
#          [0.10980392, 0.6627451 , 0.8117647 ],
#          [0.15294118, 0.7019608 , 0.84313726],
#          [0.18039216, 0.7411765 , 0.8784314 ]],
#
#         [[0.04313726, 0.14901961, 0.29411766],
#          [0.07450981, 0.19607843, 0.3372549 ],
#          [0.13725491, 0.2784314 , 0.41960785],
#          ...,
#          [0.15294118, 0.69803923, 0.8509804 ],
#          [0.1254902 , 0.68235296, 0.81960785],
#          [0.16862746, 0.7176471 , 0.85882354]]],
#
#
#        [[[0.47058824, 0.52156866, 0.5764706 ],
#          [0.4862745 , 0.5372549 , 0.5921569 ],
#          [0.40392157, 0.45882353, 0.5137255 ],
#          ...,
#          [0.41960785, 0.45490196, 0.50980395],
#          [0.42745098, 0.4627451 , 0.5176471 ],
#          [0.34509805, 0.38039216, 0.43529412]],
#
#         [[0.44705883, 0.49803922, 0.5529412 ],
#          [0.48235294, 0.53333336, 0.5882353 ],
#          [0.4392157 , 0.49019608, 0.54509807],
#          ...,
#          [0.43137255, 0.46666667, 0.52156866],
#          [0.36862746, 0.40392157, 0.45882353],
#          [0.3882353 , 0.42352942, 0.47843137]],
#
#         [[0.39607844, 0.44705883, 0.5019608 ],
#          [0.4392157 , 0.49019608, 0.54509807],
#          [0.42745098, 0.47843137, 0.53333336],
#          ...,
#          [0.41568628, 0.4509804 , 0.5058824 ],
#          [0.43529412, 0.47058824, 0.5254902 ],
#          [0.46666667, 0.5058824 , 0.5568628 ]],
#
#         ...,
#
#         [[0.14117648, 0.14901961, 0.18039216],
#          [0.10980392, 0.11764706, 0.14901961],
#          [0.10588235, 0.11372549, 0.14509805],
#          ...,
#          [0.49803922, 0.54509807, 0.6313726 ],
#          [0.6862745 , 0.7294118 , 0.8156863 ],
#          [0.7607843 , 0.8156863 , 0.90588236]],
#
#         [[0.11372549, 0.11764706, 0.16078432],
#          [0.10588235, 0.10588235, 0.14901961],
#          [0.1254902 , 0.1254902 , 0.17254902],
#          ...,
#          [0.5568628 , 0.5921569 , 0.67058825],
#          [0.49019608, 0.54509807, 0.63529414],
#          [0.6627451 , 0.7137255 , 0.8       ]],
#
#         [[0.10196079, 0.11372549, 0.12941177],
#          [0.10980392, 0.11764706, 0.14509805],
#          [0.10196079, 0.10588235, 0.14509805],
#          ...,
#          [0.39607844, 0.40392157, 0.44705883],
#          [0.56078434, 0.60784316, 0.67058825],
#          [0.56078434, 0.61960787, 0.69411767]]],
#
#
#        ...,
#
#
#        [[[0.21176471, 0.19607843, 0.27058825],
#          [0.21568628, 0.20392157, 0.26666668],
#          [0.3882353 , 0.38039216, 0.42745098],
#          ...,
#          [0.6784314 , 0.7058824 , 0.7529412 ],
#          [0.8666667 , 0.9098039 , 0.9372549 ],
#          [0.5372549 , 0.5803922 , 0.6117647 ]],
#
#         [[0.23921569, 0.22352941, 0.29411766],
#          [0.21568628, 0.20392157, 0.26666668],
#          [0.42352942, 0.41960785, 0.4627451 ],
#          ...,
#          [0.8862745 , 0.9098039 , 0.9607843 ],
#          [0.90588236, 0.9490196 , 0.9764706 ],
#          [0.5176471 , 0.56078434, 0.59607846]],
#
#         [[0.24313726, 0.23137255, 0.29411766],
#          [0.2       , 0.1882353 , 0.24705882],
#          [0.50980395, 0.5019608 , 0.54509807],
#          ...,
#          [0.79607844, 0.827451  , 0.8745098 ],
#          [0.8666667 , 0.91764706, 0.95686275],
#          [0.63529414, 0.6862745 , 0.7294118 ]],
#
#         ...,
#
#         [[0.19607843, 0.19607843, 0.21960784],
#          [0.22352941, 0.22352941, 0.24705882],
#          [0.2509804 , 0.2509804 , 0.2784314 ],
#          ...,
#          [0.21176471, 0.21568628, 0.21960784],
#          [0.21960784, 0.21960784, 0.21960784],
#          [0.23529412, 0.23529412, 0.23529412]],
#
#         [[0.20784314, 0.20784314, 0.23137255],
#          [0.21960784, 0.21960784, 0.24313726],
#          [0.22352941, 0.22352941, 0.24705882],
#          ...,
#          [0.21568628, 0.21568628, 0.21960784],
#          [0.19215687, 0.19215687, 0.19215687],
#          [0.21960784, 0.21960784, 0.21960784]],
#
#         [[0.21568628, 0.21568628, 0.23921569],
#          [0.21568628, 0.21568628, 0.23921569],
#          [0.21568628, 0.21568628, 0.23529412],
#          ...,
#          [0.24705882, 0.2509804 , 0.2509804 ],
#          [0.24313726, 0.24313726, 0.24313726],
#          [0.2784314 , 0.2784314 , 0.2784314 ]]],
#
#
#        [[[0.00392157, 0.15294118, 0.17254902],
#          [0.0627451 , 0.20784314, 0.21568628],
#          [0.00784314, 0.02745098, 0.03137255],
#          ...,
#          [0.01176471, 0.01960784, 0.13725491],
#          [0.01176471, 0.01960784, 0.10980392],
#          [0.01176471, 0.02352941, 0.08235294]],
#
#         [[0.02352941, 0.12941177, 0.1764706 ],
#          [0.01960784, 0.19607843, 0.20784314],
#          [0.        , 0.05490196, 0.06666667],
#          ...,
#          [0.01960784, 0.08627451, 0.24313726],
#          [0.        , 0.03921569, 0.15294118],
#          [0.        , 0.00784314, 0.07450981]],
#
#         [[0.04313726, 0.11372549, 0.1764706 ],
#          [0.02352941, 0.22352941, 0.24705882],
#          [0.        , 0.15686275, 0.16470589],
#          ...,
#          [0.02352941, 0.15686275, 0.29803923],
#          [0.        , 0.07450981, 0.20392157],
#          [0.02352941, 0.05882353, 0.16078432]],
#
#         ...,
#
#         [[0.20392157, 0.59607846, 0.5764706 ],
#          [0.23137255, 0.6392157 , 0.61960787],
#          [0.19215687, 0.60784316, 0.58431375],
#          ...,
#          [0.02745098, 0.41568628, 0.4509804 ],
#          [0.07450981, 0.40784314, 0.45490196],
#          [0.03529412, 0.3137255 , 0.35686275]],
#
#         [[0.22745098, 0.6       , 0.58431375],
#          [0.22745098, 0.62352943, 0.6039216 ],
#          [0.23921569, 0.61960787, 0.60784316],
#          ...,
#          [0.04705882, 0.43137255, 0.47058824],
#          [0.03921569, 0.37254903, 0.41960785],
#          [0.03529412, 0.32156864, 0.36862746]],
#
#         [[0.21568628, 0.5764706 , 0.5568628 ],
#          [0.22352941, 0.6       , 0.5764706 ],
#          [0.21176471, 0.62352943, 0.5882353 ],
#          ...,
#          [0.07058824, 0.43137255, 0.48235294],
#          [0.02352941, 0.3764706 , 0.41960785],
#          [0.03529412, 0.29411766, 0.3529412 ]]],
#
#
#        [[[0.22745098, 0.2509804 , 0.23137255],
#          [0.20392157, 0.22745098, 0.20784314],
#          [0.21568628, 0.23921569, 0.21960784],
#          ...,
#          [0.3882353 , 0.3882353 , 0.3882353 ],
#          [0.37254903, 0.37254903, 0.37254903],
#          [0.42352942, 0.41960785, 0.41568628]],
#
#         [[0.22352941, 0.2509804 , 0.22745098],
#          [0.23137255, 0.25490198, 0.23529412],
#          [0.22352941, 0.24705882, 0.22745098],
#          ...,
#          [0.35686275, 0.35686275, 0.35686275],
#          [0.34509805, 0.34509805, 0.34509805],
#          [0.3647059 , 0.3647059 , 0.35686275]],
#
#         [[0.22745098, 0.2509804 , 0.23137255],
#          [0.21568628, 0.23921569, 0.21960784],
#          [0.23921569, 0.2627451 , 0.24313726],
#          ...,
#          [0.4       , 0.4       , 0.4       ],
#          [0.39215687, 0.39215687, 0.39215687],
#          [0.40392157, 0.41960785, 0.41568628]],
#
#         ...,
#
#         [[0.6313726 , 0.64705884, 0.6666667 ],
#          [0.6156863 , 0.6313726 , 0.6509804 ],
#          [0.6666667 , 0.6901961 , 0.70980394],
#          ...,
#          [0.68235296, 0.7137255 , 0.7411765 ],
#          [0.49411765, 0.5294118 , 0.56078434],
#          [0.59607846, 0.63529414, 0.654902  ]],
#
#         [[0.6745098 , 0.7137255 , 0.7294118 ],
#          [0.6431373 , 0.6784314 , 0.6901961 ],
#          [0.62352943, 0.65882355, 0.6745098 ],
#          ...,
#          [0.63529414, 0.6745098 , 0.6745098 ],
#          [0.627451  , 0.7137255 , 0.7019608 ],
#          [0.6313726 , 0.6666667 , 0.6745098 ]],
#
#         [[0.6392157 , 0.6745098 , 0.6901961 ],
#          [0.654902  , 0.6901961 , 0.7058824 ],
#          [0.6666667 , 0.69411767, 0.7137255 ],
#          ...,
#          [0.6666667 , 0.69803923, 0.7254902 ],
#          [0.59607846, 0.6627451 , 0.6901961 ],
#          [0.61960787, 0.6509804 , 0.6745098 ]]]], dtype=float32)

# %%
labels
# Out:
# array(['gatinhos', 'gatinhos', 'gatinhos', ..., 'cachorrinhos',
#        'cachorrinhos', 'cachorrinhos'], dtype='<U12')

# %% [markdown]
# ## Construindo um dataframe
#
# Com as imagens e rótulos já definidos, vamos contruir um dataframe com o nome e o rótulo da imagem.

# %%
# Salvando a lista de caminhos de arquivo
pd_filepaths = pd.Series(filepaths, name='Filepath').astype(str)

# %%
# Visualizando o caminho das imagens
print(pd_filepaths[:3])
# Out:
# 0    /content/drive/My Drive/cat_dog_images/gatinho...
# 1    /content/drive/My Drive/cat_dog_images/gatinho...
# 2    /content/drive/My Drive/cat_dog_images/gatinho...
# Name: Filepath, dtype: object

# %%
# Visualizando os rótulos das imagens
print(labels[:3])
# Out:
# ['gatinhos' 'gatinhos' 'gatinhos']

# %%
# Adionando a label
pd_labels = pd.Series(labels, name='Label')

# %%
pd_labels
# Out:
# 0           gatinhos
# 1           gatinhos
# 2           gatinhos
# 3           gatinhos
# 4           gatinhos
#             ...
# 1600    cachorrinhos
# 1601    cachorrinhos
# 1602    cachorrinhos
# 1603    cachorrinhos
# 1604    cachorrinhos
# Name: Label, Length: 1605, dtype: object

# %%
# Concatenando o filepaths e labels
df = pd.concat([pd_filepaths, pd_labels], axis=1)

# %%
df.head()
# Out:
#                                             Filepath     Label
# 0  /content/drive/My Drive/cat_dog_images/gatinho...  gatinhos
# 1  /content/drive/My Drive/cat_dog_images/gatinho...  gatinhos
# 2  /content/drive/My Drive/cat_dog_images/gatinho...  gatinhos
# 3  /content/drive/My Drive/cat_dog_images/gatinho...  gatinhos
# 4  /content/drive/My Drive/cat_dog_images/gatinho...  gatinhos

# %%
df.tail()
# Out:
#                                                Filepath         Label
# 1600  /content/drive/My Drive/cat_dog_images/cachorr...  cachorrinhos
# 1601  /content/drive/My Drive/cat_dog_images/cachorr...  cachorrinhos
# 1602  /content/drive/My Drive/cat_dog_images/cachorr...  cachorrinhos
# 1603  /content/drive/My Drive/cat_dog_images/cachorr...  cachorrinhos
# 1604  /content/drive/My Drive/cat_dog_images/cachorr...  cachorrinhos

# %% [markdown]
# Perceba que nossos dados estão em ordem das classes, isso pode ser um problema para o modelo, então vamos utilizar o sample para embaralhar o dataframe:

# %%
# Embaralhando o dataframe
df = df.sample(frac=1).reset_index(drop=True)

# %%
df.head()
# Out:
#                                             Filepath         Label
# 0  /content/drive/My Drive/cat_dog_images/cachorr...  cachorrinhos
# 1  /content/drive/My Drive/cat_dog_images/gatinho...      gatinhos
# 2  /content/drive/My Drive/cat_dog_images/gatinho...      gatinhos
# 3  /content/drive/My Drive/cat_dog_images/cachorr...  cachorrinhos
# 4  /content/drive/My Drive/cat_dog_images/gatinho...      gatinhos

# %%
# Cria uma cópia do dataframe com apenas uma imagem de cada animal

# o subset está procurando por duplicatas apenas na coluna chamada 'Label' e removendo todas as duplicatas encontradas.
df_singles = df.copy().drop_duplicates(subset=('Label')).reset_index()

# %%
len(df_singles)
# Out:
# 2

# %%
# Define o número de classes
num_classes = df_singles.shape[0]

# %% [markdown]
# Show! Agora que temos as classes mapeadas na variável num_classes, vamos visualizar duas amostras de imagens dentro do dataset:

# %%
# Configura o número de linhas e colunas para vizualizar os dados no plot
ROW = 1
COLUMN = 2

# Dimensões das imagens
plt.figure(figsize=(12, 9))
# Loop para cada animal
for i in range(num_classes):
  # Defina uma variável de imagem local para i imagem no dataframe de singles
  image = df_singles.Filepath[i]
  # Define a posição da imagem a ser plotada
  plt.subplot(ROW, COLUMN, i+1)
  # Mostra a imagem
  plt.imshow(plt.imread(image))
  # Adiciona o rótulo do bichinho que corresponde à imagem
  plt.title('{}'.format(df_singles.Label[i]))
  # Desliga o eixo de plotagem
  plt.axis('off')
  # Faça com que o preenchimento ao redor das imagens seja mínimo
  plt.tight_layout()
plt.show()

# %% [markdown]
# ## Separando em treino e teste a base de dados
#
# Agora com as imagens e classes organizados, podemos aplicar o train_test_split para separar as bases de treinamento e teste:

# %%
x_train, x_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, stratify=labels, random_state=44)

# %%
# Analisando a dimensão dos dados
x_train.shape
# Out:
# (1284, 64, 64, 3)

# %%
x_test.shape
# Out:
# (321, 64, 64, 3)

# %%
images
# Out:
# array([[[[0.3529412 , 0.654902  , 0.80784315],
#          [0.3764706 , 0.6784314 , 0.83137256],
#          [0.39607844, 0.7019608 , 0.87058824],
#          ...,
#          [0.5411765 , 0.84313726, 0.972549  ],
#          [0.5019608 , 0.81960785, 0.96862745],
#          [0.47843137, 0.8       , 0.9529412 ]],
#
#         [[0.3529412 , 0.654902  , 0.80784315],
#          [0.3764706 , 0.6784314 , 0.83137256],
#          [0.39607844, 0.7019608 , 0.87058824],
#          ...,
#          [0.5568628 , 0.85490197, 0.96862745],
#          [0.5254902 , 0.83137256, 0.96862745],
#          [0.49411765, 0.80784315, 0.95686275]],
#
#         [[0.3529412 , 0.654902  , 0.80784315],
#          [0.3764706 , 0.6784314 , 0.83137256],
#          [0.39607844, 0.7019608 , 0.87058824],
#          ...,
#          [0.5686275 , 0.8509804 , 0.96862745],
#          [0.5529412 , 0.84705883, 0.96862745],
#          [0.5137255 , 0.81960785, 0.96862745]],
#
#         ...,
#
#         [[0.22352941, 0.5019608 , 0.63529414],
#          [0.23921569, 0.5176471 , 0.6509804 ],
#          [0.24705882, 0.5254902 , 0.67058825],
#          ...,
#          [0.        , 0.01568628, 0.01176471],
#          [0.        , 0.01568628, 0.01176471],
#          [0.        , 0.01176471, 0.00784314]],
#
#         [[0.21176471, 0.49019608, 0.627451  ],
#          [0.22352941, 0.5019608 , 0.63529414],
#          [0.23137255, 0.50980395, 0.654902  ],
#          ...,
#          [0.        , 0.01568628, 0.01176471],
#          [0.        , 0.01568628, 0.01176471],
#          [0.        , 0.01176471, 0.00784314]],
#
#         [[0.21960784, 0.48235294, 0.6039216 ],
#          [0.23529412, 0.5019608 , 0.61960787],
#          [0.22745098, 0.50980395, 0.6431373 ],
#          ...,
#          [0.        , 0.00784314, 0.00784314],
#          [0.        , 0.00784314, 0.00784314],
#          [0.        , 0.00784314, 0.00784314]]],
#
#
#        [[[0.32941177, 0.37254903, 0.40392157],
#          [0.40392157, 0.44705883, 0.47843137],
#          [0.4117647 , 0.45490196, 0.4862745 ],
#          ...,
#          [0.9647059 , 0.9647059 , 0.9647059 ],
#          [0.92941177, 0.9490196 , 0.94509804],
#          [0.9372549 , 0.95686275, 0.9529412 ]],
#
#         [[0.32941177, 0.37254903, 0.40392157],
#          [0.40392157, 0.44705883, 0.47843137],
#          [0.41568628, 0.45490196, 0.49019608],
#          ...,
#          [0.9529412 , 0.9529412 , 0.9529412 ],
#          [0.93333334, 0.9529412 , 0.9490196 ],
#          [0.9411765 , 0.9607843 , 0.95686275]],
#
#         [[0.32941177, 0.37254903, 0.40392157],
#          [0.40392157, 0.44705883, 0.47843137],
#          [0.41568628, 0.45882353, 0.49411765],
#          ...,
#          [0.9411765 , 0.9411765 , 0.9411765 ],
#          [0.9372549 , 0.95686275, 0.9529412 ],
#          [0.94509804, 0.9647059 , 0.9607843 ]],
#
#         ...,
#
#         [[0.03137255, 0.09803922, 0.21568628],
#          [0.01568628, 0.08235294, 0.20392157],
#          [0.        , 0.07058824, 0.1882353 ],
#          ...,
#          [0.10588235, 0.60784316, 0.7647059 ],
#          [0.19215687, 0.7137255 , 0.85882354],
#          [0.17254902, 0.73333335, 0.87058824]],
#
#         [[0.02352941, 0.11372549, 0.24313726],
#          [0.01568628, 0.11372549, 0.24705882],
#          [0.07843138, 0.1882353 , 0.32156864],
#          ...,
#          [0.10980392, 0.6627451 , 0.8117647 ],
#          [0.15294118, 0.7019608 , 0.84313726],
#          [0.18039216, 0.7411765 , 0.8784314 ]],
#
#         [[0.04313726, 0.14901961, 0.29411766],
#          [0.07450981, 0.19607843, 0.3372549 ],
#          [0.13725491, 0.2784314 , 0.41960785],
#          ...,
#          [0.15294118, 0.69803923, 0.8509804 ],
#          [0.1254902 , 0.68235296, 0.81960785],
#          [0.16862746, 0.7176471 , 0.85882354]]],
#
#
#        [[[0.47058824, 0.52156866, 0.5764706 ],
#          [0.4862745 , 0.5372549 , 0.5921569 ],
#          [0.40392157, 0.45882353, 0.5137255 ],
#          ...,
#          [0.41960785, 0.45490196, 0.50980395],
#          [0.42745098, 0.4627451 , 0.5176471 ],
#          [0.34509805, 0.38039216, 0.43529412]],
#
#         [[0.44705883, 0.49803922, 0.5529412 ],
#          [0.48235294, 0.53333336, 0.5882353 ],
#          [0.4392157 , 0.49019608, 0.54509807],
#          ...,
#          [0.43137255, 0.46666667, 0.52156866],
#          [0.36862746, 0.40392157, 0.45882353],
#          [0.3882353 , 0.42352942, 0.47843137]],
#
#         [[0.39607844, 0.44705883, 0.5019608 ],
#          [0.4392157 , 0.49019608, 0.54509807],
#          [0.42745098, 0.47843137, 0.53333336],
#          ...,
#          [0.41568628, 0.4509804 , 0.5058824 ],
#          [0.43529412, 0.47058824, 0.5254902 ],
#          [0.46666667, 0.5058824 , 0.5568628 ]],
#
#         ...,
#
#         [[0.14117648, 0.14901961, 0.18039216],
#          [0.10980392, 0.11764706, 0.14901961],
#          [0.10588235, 0.11372549, 0.14509805],
#          ...,
#          [0.49803922, 0.54509807, 0.6313726 ],
#          [0.6862745 , 0.7294118 , 0.8156863 ],
#          [0.7607843 , 0.8156863 , 0.90588236]],
#
#         [[0.11372549, 0.11764706, 0.16078432],
#          [0.10588235, 0.10588235, 0.14901961],
#          [0.1254902 , 0.1254902 , 0.17254902],
#          ...,
#          [0.5568628 , 0.5921569 , 0.67058825],
#          [0.49019608, 0.54509807, 0.63529414],
#          [0.6627451 , 0.7137255 , 0.8       ]],
#
#         [[0.10196079, 0.11372549, 0.12941177],
#          [0.10980392, 0.11764706, 0.14509805],
#          [0.10196079, 0.10588235, 0.14509805],
#          ...,
#          [0.39607844, 0.40392157, 0.44705883],
#          [0.56078434, 0.60784316, 0.67058825],
#          [0.56078434, 0.61960787, 0.69411767]]],
#
#
#        ...,
#
#
#        [[[0.21176471, 0.19607843, 0.27058825],
#          [0.21568628, 0.20392157, 0.26666668],
#          [0.3882353 , 0.38039216, 0.42745098],
#          ...,
#          [0.6784314 , 0.7058824 , 0.7529412 ],
#          [0.8666667 , 0.9098039 , 0.9372549 ],
#          [0.5372549 , 0.5803922 , 0.6117647 ]],
#
#         [[0.23921569, 0.22352941, 0.29411766],
#          [0.21568628, 0.20392157, 0.26666668],
#          [0.42352942, 0.41960785, 0.4627451 ],
#          ...,
#          [0.8862745 , 0.9098039 , 0.9607843 ],
#          [0.90588236, 0.9490196 , 0.9764706 ],
#          [0.5176471 , 0.56078434, 0.59607846]],
#
#         [[0.24313726, 0.23137255, 0.29411766],
#          [0.2       , 0.1882353 , 0.24705882],
#          [0.50980395, 0.5019608 , 0.54509807],
#          ...,
#          [0.79607844, 0.827451  , 0.8745098 ],
#          [0.8666667 , 0.91764706, 0.95686275],
#          [0.63529414, 0.6862745 , 0.7294118 ]],
#
#         ...,
#
#         [[0.19607843, 0.19607843, 0.21960784],
#          [0.22352941, 0.22352941, 0.24705882],
#          [0.2509804 , 0.2509804 , 0.2784314 ],
#          ...,
#          [0.21176471, 0.21568628, 0.21960784],
#          [0.21960784, 0.21960784, 0.21960784],
#          [0.23529412, 0.23529412, 0.23529412]],
#
#         [[0.20784314, 0.20784314, 0.23137255],
#          [0.21960784, 0.21960784, 0.24313726],
#          [0.22352941, 0.22352941, 0.24705882],
#          ...,
#          [0.21568628, 0.21568628, 0.21960784],
#          [0.19215687, 0.19215687, 0.19215687],
#          [0.21960784, 0.21960784, 0.21960784]],
#
#         [[0.21568628, 0.21568628, 0.23921569],
#          [0.21568628, 0.21568628, 0.23921569],
#          [0.21568628, 0.21568628, 0.23529412],
#          ...,
#          [0.24705882, 0.2509804 , 0.2509804 ],
#          [0.24313726, 0.24313726, 0.24313726],
#          [0.2784314 , 0.2784314 , 0.2784314 ]]],
#
#
#        [[[0.00392157, 0.15294118, 0.17254902],
#          [0.0627451 , 0.20784314, 0.21568628],
#          [0.00784314, 0.02745098, 0.03137255],
#          ...,
#          [0.01176471, 0.01960784, 0.13725491],
#          [0.01176471, 0.01960784, 0.10980392],
#          [0.01176471, 0.02352941, 0.08235294]],
#
#         [[0.02352941, 0.12941177, 0.1764706 ],
#          [0.01960784, 0.19607843, 0.20784314],
#          [0.        , 0.05490196, 0.06666667],
#          ...,
#          [0.01960784, 0.08627451, 0.24313726],
#          [0.        , 0.03921569, 0.15294118],
#          [0.        , 0.00784314, 0.07450981]],
#
#         [[0.04313726, 0.11372549, 0.1764706 ],
#          [0.02352941, 0.22352941, 0.24705882],
#          [0.        , 0.15686275, 0.16470589],
#          ...,
#          [0.02352941, 0.15686275, 0.29803923],
#          [0.        , 0.07450981, 0.20392157],
#          [0.02352941, 0.05882353, 0.16078432]],
#
#         ...,
#
#         [[0.20392157, 0.59607846, 0.5764706 ],
#          [0.23137255, 0.6392157 , 0.61960787],
#          [0.19215687, 0.60784316, 0.58431375],
#          ...,
#          [0.02745098, 0.41568628, 0.4509804 ],
#          [0.07450981, 0.40784314, 0.45490196],
#          [0.03529412, 0.3137255 , 0.35686275]],
#
#         [[0.22745098, 0.6       , 0.58431375],
#          [0.22745098, 0.62352943, 0.6039216 ],
#          [0.23921569, 0.61960787, 0.60784316],
#          ...,
#          [0.04705882, 0.43137255, 0.47058824],
#          [0.03921569, 0.37254903, 0.41960785],
#          [0.03529412, 0.32156864, 0.36862746]],
#
#         [[0.21568628, 0.5764706 , 0.5568628 ],
#          [0.22352941, 0.6       , 0.5764706 ],
#          [0.21176471, 0.62352943, 0.5882353 ],
#          ...,
#          [0.07058824, 0.43137255, 0.48235294],
#          [0.02352941, 0.3764706 , 0.41960785],
#          [0.03529412, 0.29411766, 0.3529412 ]]],
#
#
#        [[[0.22745098, 0.2509804 , 0.23137255],
#          [0.20392157, 0.22745098, 0.20784314],
#          [0.21568628, 0.23921569, 0.21960784],
#          ...,
#          [0.3882353 , 0.3882353 , 0.3882353 ],
#          [0.37254903, 0.37254903, 0.37254903],
#          [0.42352942, 0.41960785, 0.41568628]],
#
#         [[0.22352941, 0.2509804 , 0.22745098],
#          [0.23137255, 0.25490198, 0.23529412],
#          [0.22352941, 0.24705882, 0.22745098],
#          ...,
#          [0.35686275, 0.35686275, 0.35686275],
#          [0.34509805, 0.34509805, 0.34509805],
#          [0.3647059 , 0.3647059 , 0.35686275]],
#
#         [[0.22745098, 0.2509804 , 0.23137255],
#          [0.21568628, 0.23921569, 0.21960784],
#          [0.23921569, 0.2627451 , 0.24313726],
#          ...,
#          [0.4       , 0.4       , 0.4       ],
#          [0.39215687, 0.39215687, 0.39215687],
#          [0.40392157, 0.41960785, 0.41568628]],
#
#         ...,
#
#         [[0.6313726 , 0.64705884, 0.6666667 ],
#          [0.6156863 , 0.6313726 , 0.6509804 ],
#          [0.6666667 , 0.6901961 , 0.70980394],
#          ...,
#          [0.68235296, 0.7137255 , 0.7411765 ],
#          [0.49411765, 0.5294118 , 0.56078434],
#          [0.59607846, 0.63529414, 0.654902  ]],
#
#         [[0.6745098 , 0.7137255 , 0.7294118 ],
#          [0.6431373 , 0.6784314 , 0.6901961 ],
#          [0.62352943, 0.65882355, 0.6745098 ],
#          ...,
#          [0.63529414, 0.6745098 , 0.6745098 ],
#          [0.627451  , 0.7137255 , 0.7019608 ],
#          [0.6313726 , 0.6666667 , 0.6745098 ]],
#
#         [[0.6392157 , 0.6745098 , 0.6901961 ],
#          [0.654902  , 0.6901961 , 0.7058824 ],
#          [0.6666667 , 0.69411767, 0.7137255 ],
#          ...,
#          [0.6666667 , 0.69803923, 0.7254902 ],
#          [0.59607846, 0.6627451 , 0.6901961 ],
#          [0.61960787, 0.6509804 , 0.6745098 ]]]], dtype=float32)

# %% [markdown]
# Sabemos que as imagens são basicamente uma matriz de pixels e para colocar as imagens dentro da arquitetura das redes convolucionais, é preciso "achatar" essas matrizes multidimensionais em vetores unidimensionais. Uma das camadas da rede, a Flatten(), é uma das partes da rede que achata os dados antes de entrar nas camadas densas.

# %%
# Achatar os dados de teste e treinamento
x_train_flat = x_train.reshape(x_train.shape[0], x_train.shape[1]*x_train.shape[2]*x_train.shape[3])
x_test_flat = x_test.reshape(x_test.shape[0], x_test.shape[1]*x_test.shape[2]*x_test.shape[3])

# %%
# Visualizando a transformação
x_train_flat.shape
# Out:
# (1284, 12288)

# %% [markdown]
# Como próximo passo, vamos converter as classes de texto em binárias. Para esse procedimento, vamos utilizar o método LabelEncoder().

# %%
# Converter Strings em Numéricos
label_encoder = LabelEncoder()

y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.fit_transform(y_test)

# Converter um vetor de classe (inteiros) em uma matriz de classe categórica
y_train_tf = keras.utils.to_categorical(y_train, num_classes)
y_test_tf = keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# Vamos configurar agora como próximo passo o ModelCheckpoint para usar os melhores pesos para este modelo. Um dos benefícios do ModelCheckpoint é salvar uma cópia do modelo em disco em intervalos regulares (como após cada época de processamento) para que você possa retomar o treinamento a partir do ponto em que parou, minimizando perdas de tempo e recursos computacionais.

# %%
from distutils.file_util import copy_file

# Define um objeto ModelCheckpoint para usar os melhores pesos para este modelo

# versão chatGPT
checkpointer = ModelCheckpoint(filepath="weights.best.keras", verbose=0, save_best_only=True) # save best model


# versão do curso - não funciona atualmente por causa da versão atual do keras
# checkpointer = ModelCheckpoint(filepath="weights.best.hdf5", verbose=0, save_best_only=True) # save best model

# %% [markdown]
# Como próximo passo, vamos definir a entrada da rede e armazenar na variável
#
# **input_shape** e em seguida configurar a learning rate e a queda do peso do otimizador com **weight_decay**.
#
# O argumento weight_decay é usado para aplicar **regularização L2** (também conhecida como regularização de peso) às camadas densas (fully connected) de uma rede neural durante o treinamento. A regularização L2 funciona adicionando um termo à função de perda durante o treinamento que penaliza os pesos maiores.

# %%
# Define a forma de entrada das imagens passadas pelo modelo
input_shape = (image_size, image_size, 3)

# Define a taxa de aprendizado e a queda de peso para o otimizador usar
learning_rate = 0.001

# %% [markdown]
# Agora chegou o momento tão esperado, nossa rede neural convolucional!
#
# Acompanhe comigo o código a seguir e vamos comentando sobre cada passo da contrução da rede:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
tf.random.set_seed(42) # Definindo uma semente aleatória para utilizar sempre os mesmos dados durante nossos testes

model = Sequential() # Abrindo a sequencia do modelo

# 1 camada convolucional com 128 neurônios | filtro utilizando uma matriz 3x3 sendo movimentado por um stride de 2
# padding ativado (com bordas de zeros) | função de ativação ReLU | regularização L2 ativada
model.add(Conv2D(128,
                 kernel_size=(3,3),
                 strides=(2,2),
                 padding='same',
                 activation='relu',
                 kernel_regularizer=keras.regularizers.l2(0.001),
                 input_shape=input_shape)),

# Camada de MaxPolling ativada, com uma matriz 2x2. Padding ativado
model.add(MaxPooling2D(pool_size=(2,2), strides=None, padding='same'))

# Regularização de dropout ativada
model.add(Dropout(0.2))

# 2 camada convolucional com 92 neurônios | filtro utilizando uma matriz 3x3 sendo movimentado por um stride de 2
# padding ativado (com bordas de zeros) | função de ativação ReLU | regularização L2 ativada
model.add(Conv2D(92,
                 kernel_size=(3,3),
                 strides=(2,2),
                 padding='same',
                 activation='relu',
                 kernel_regularizer=keras.regularizers.l2(0.001))),

# Camada de MaxPooling ativada, com uma matriz 2x2. Padding ativado
model.add(MaxPooling2D(pool_size=(2,2), strides=None, padding='same'))

# Regularização de dropout ativada
model.add(Dropout(0.2))

# Camada que achata os dados da imagem
model.add(Flatten())
# Camada Dense da rede neural convolucional + função de ativação ReLU
model.add(Dense(256, activation='relu'))
# Camada de saída da rede, utilizando a função de ativação softmax para criar a probabilidade de pertecimento das classes
# model.add(Dense(y_train_tf.shape[1], activation='softmax'))
# Camada de saída da rede, utilizando a função de ativação sigmoid para classificação binária
model.add(Dense(y_train_tf.shape[1], activation='sigmoid'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Agora vamos configurar uma técnica de validação do modelo para evitar que as épocas de processamento não executem o modelo sem ter melhoras significativas, o **early stopping**. Essa técnica monitora a perda no conjunto de validação e interrompe o treinamento se a perda não diminuir significativamente por um número especificado de épocas (10 no exemplo) após uma pequena melhoria (mínimo delta de 1e-5). Essa é uma **técnica útil para evitar o overfitting e economizar tempo de treinamento**. (Podemos dizer que essa técnica ajuda o modelo a não ficar "estagnado", ou seja, se encontra em estado estacionário).
#
# Além da configuração do early stopping, vamos configurar a função de custo com o **Adam**. A função de custo tem o papel de **ajustar os pesos de uma rede neural durante o treinamento**. o Adam também utiliza um termo de momentum para acelerar o processo de aprendizado. O momentum **ajuda o algoritmo a superar regiões planas ou mínimos locais rasos**, permitindo que ele "ganhe velocidade" na direção do mínimo global. O otimizador Adam requer menos configuração de hiperparâmetro da taxa de aprendizagem, então um valor padrão n = 0,001 pode ser uma boa opção!
#
# Lembrando que a **taxa de aprendizagem** (learning rate) é responsável por controlar o tamanho dos “passos” das interações para encontrar um melhor mínimo local (menor erro). Uma taxa de aprendizagem baixa pode ser mais precisa, porém pode demorar para encontrar o mínimo local. Uma taxa de aprendizado alta pode deixar passar o melhor mínimo local.

# %%
# Monitor para interromper o modelo antecipadamente quando a melhoria da perda de validação for mínima
monitor = EarlyStopping(monitor='val_loss', min_delta=1e-5, patience=10, verbose=1, mode='auto') # Aqui utilizando early stopp

# Compilando o modelo e aplicação a função de custo Adam (utilizando a learning rate que configuramos anteriormente)
# model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate), metrics=['accuracy'])

# binary_crossentropy - trabalha melhor com o sigmoid
model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate), metrics=['accuracy'])

# Salve os dados do modelo em um arquivo h5
model.save('./cat_dog.h5')
# Resumo do modelo
model.summary()
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 128)         │           3,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 8, 8, 92)            │         106,076 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 4, 4, 92)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 4, 4, 92)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 1472)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         377,088 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 2)                   │             514 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 487,262 (1.86 MB)
#  Trainable params: 487,262 (1.86 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Por fim, vamos configurar o número de épocas de processamento em conjunto com a base de validação das épocas. Nesse momento também é importante configurar o número de batchs que o modelo irá processar por épocas para atualizar os pesos. Em outras palavras, as batchs são as quantidades de dados de treinamento que são processadas de uma só vez antes que os pesos do modelo sejam atualizados com base nos gradientes calculados.

# %%
# Treinando o modelo
history = model.fit(x_train, y_train_tf, validation_split=0.25, callbacks=[monitor, checkpointer],
                    verbose=1, epochs=45, batch_size=50, shuffle=True)
# Out:
# Epoch 1/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 201ms/step - accuracy: 0.4835 - loss: 0.8113 - val_accuracy: 0.5109 - val_loss: 0.7682
# Epoch 2/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - accuracy: 0.4944 - loss: 0.7614 - val_accuracy: 0.5265 - val_loss: 0.7424
# Epoch 3/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 229ms/step - accuracy: 0.5207 - loss: 0.7400 - val_accuracy: 0.5389 - val_loss: 0.7265
# Epoch 4/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 240ms/step - accuracy: 0.5469 - loss: 0.7226 - val_accuracy: 0.4984 - val_loss: 0.7559
# Epoch 5/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 185ms/step - accuracy: 0.5230 - loss: 0.7374 - val_accuracy: 0.6012 - val_loss: 0.7091
# Epoch 6/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - accuracy: 0.5447 - loss: 0.7097 - val_accuracy: 0.5327 - val_loss: 0.7211
# Epoch 7/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 244ms/step - accuracy: 0.5714 - loss: 0.7131 - val_accuracy: 0.6012 - val_loss: 0.6896
# Epoch 8/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - accuracy: 0.6074 - loss: 0.6868 - val_accuracy: 0.5514 - val_loss: 0.7057
# Epoch 9/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 183ms/step - accuracy: 0.6059 - loss: 0.6937 - val_accuracy: 0.5857 - val_loss: 0.6849
# Epoch 10/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 278ms/step - accuracy: 0.6325 - loss: 0.6661 - val_accuracy: 0.5950 - val_loss: 0.7012
# Epoch 11/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - accuracy: 0.6560 - loss: 0.6551 - val_accuracy: 0.5857 - val_loss: 0.6939
# Epoch 12/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 181ms/step - accuracy: 0.6603 - loss: 0.6414 - val_accuracy: 0.5888 - val_loss: 0.6772
# Epoch 13/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 247ms/step - accuracy: 0.6835 - loss: 0.6201 - val_accuracy: 0.6791 - val_loss: 0.6305
# Epoch 14/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 205ms/step - accuracy: 0.6917 - loss: 0.5918 - val_accuracy: 0.6760 - val_loss: 0.6319
# Epoch 15/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 169ms/step - accuracy: 0.7106 - loss: 0.5685 - val_accuracy: 0.6822 - val_loss: 0.6314
# Epoch 16/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 220ms/step - accuracy: 0.7268 - loss: 0.5400 - val_accuracy: 0.6916 - val_loss: 0.6177
# Epoch 17/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 232ms/step - accuracy: 0.7539 - loss: 0.5111 - val_accuracy: 0.6854 - val_loss: 0.6588
# Epoch 18/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 162ms/step - accuracy: 0.7664 - loss: 0.4878 - val_accuracy: 0.7259 - val_loss: 0.6174
# Epoch 19/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 200ms/step - accuracy: 0.7988 - loss: 0.4559 - val_accuracy: 0.7196 - val_loss: 0.6260
# Epoch 20/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 270ms/step - accuracy: 0.8178 - loss: 0.4423 - val_accuracy: 0.7290 - val_loss: 0.6142
# Epoch 21/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 179ms/step - accuracy: 0.8040 - loss: 0.4281 - val_accuracy: 0.6978 - val_loss: 0.6668
# Epoch 22/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 278ms/step - accuracy: 0.8444 - loss: 0.3810 - val_accuracy: 0.6885 - val_loss: 0.6577
# Epoch 23/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 177ms/step - accuracy: 0.8595 - loss: 0.3793 - val_accuracy: 0.7072 - val_loss: 0.6757
# Epoch 24/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 276ms/step - accuracy: 0.8456 - loss: 0.3466 - val_accuracy: 0.6573 - val_loss: 0.7894
# Epoch 25/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 170ms/step - accuracy: 0.8685 - loss: 0.3280 - val_accuracy: 0.6916 - val_loss: 0.7740
# Epoch 26/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 7s 270ms/step - accuracy: 0.8862 - loss: 0.3158 - val_accuracy: 0.7009 - val_loss: 0.7354
# Epoch 27/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - accuracy: 0.8821 - loss: 0.3102 - val_accuracy: 0.7196 - val_loss: 0.7103
# Epoch 28/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - accuracy: 0.8987 - loss: 0.2898 - val_accuracy: 0.7134 - val_loss: 0.7639
# Epoch 29/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 245ms/step - accuracy: 0.9095 - loss: 0.2667 - val_accuracy: 0.7072 - val_loss: 0.7613
# Epoch 30/45
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 5s 244ms/step - accuracy: 0.9278 - loss: 0.2385 - val_accuracy: 0.7072 - val_loss: 0.7682
# Epoch 30: early stopping

# %% [markdown]
# ## Validação do modelo
#
# Existem duas métricas importantes que devemos analisar após executar a rede neural, o valor do erro observado e o valor de acurácia por épocas de processamento. Uma boa prática é analisarmos com gráficos de linhas para identidicarmos as tedências da perfomance da rede.

# %%
# Validação o erro por épocas
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.grid(True)
plt.show()

# %%
# Validação da acurácia por épocas
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.grid(True)
plt.show()

# %% [markdown]
# Show! Agora vamos armazenar as predições da base de teste na variável de predição **cnn_pred_cat_dog**:

# %%
# Armazena as predições do modelo dos dados de teste em uma variável
cnn_pred_cat_dog = model.predict(x_test)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step

# %% [markdown]
# Em seguida, vamos utilizar o argmax do numppy para encontrar a classe com a maior probabilidade prevista para cada amostra. (Lembrando que utilizamos a softmax).

# %%
# Define o índice do valor máximo de previsão para uma variável
# O valor máximo indica o caractere de previsão do modelo que a imagem representa
cnn_pred_cat_dog = np.argmax(cnn_pred_cat_dog, axis=1)

# Define uma variável para armazenar o rótulo que representa o resultado verdadeiro
y_true = np.argmax(y_test_tf, axis=1)

# %% [markdown]
# Agora vamos organizar os nomes dos animais (gatinhos e cachorrinhos) em uma variável, a fim de criar uma lista única de nomes de animais, ordenados alfabeticamente. Vamos também remover duplicatas e ordenar os nomes em ordem alfabética, resultando em uma lista única, limpa e ordenada de nomes de animais.

# %%
# Cria um array de nomes de caracteres igual ao array de labels
animal_names = labels
# Reduza os nomes dos animais para apenas valores dict únicos
animal_names = list(dict.fromkeys(animal_names))
# Ordena os caracteres em ordem alfabética, qual é a ordem em que os dados são alimentados
animal_names = sorted(animal_names)

# %% [markdown]
# Importante analisar o escopo das classes, então vamos utilizar o classification_report e analisar os resultados por escopo das variáveis targets.

# %%
# Criando uma matriz de confusão
cnn_cm_cat_dog = metrics.confusion_matrix(y_true, cnn_pred_cat_dog)

# Definindo a acurácia
cnn_accuracy_cat_dog = metrics.accuracy_score(y_true, cnn_pred_cat_dog)

# Print do Classification report
print(metrics.classification_report(y_true, cnn_pred_cat_dog, target_names=animal_names))
# Print da acurácia
print('Accuracy score: {}'.format(cnn_accuracy_cat_dog))
# Out:
#               precision    recall  f1-score   support
#
# cachorrinhos       0.70      0.80      0.75       160
#     gatinhos       0.77      0.66      0.71       161
#
#     accuracy                           0.73       321
#    macro avg       0.73      0.73      0.73       321
# weighted avg       0.73      0.73      0.73       321
#
# Accuracy score: 0.7289719626168224

# %% [markdown]
# Por fim, vamos criar uma função para adivinhar os animaizinhos?

# %%
# Função para adivinhar o animal
def guess_animal(filepath):
  # Convete o caminho do arquivo para uma imagem
  image = cv2.imread(filepath)
  # Redimensione a imagem e normalize o intervalo de pixels para ficar entre 0 e 1
  img = cv2.resize(image, (image_size, image_size)).astype('float32') / 255.0
  # Expandir a forma do array de imagens
  img = np.expand_dims(img, axis=0)
  # Usando o modelo para prever o animal que representa a imagem
  pred = model.predict(img)
  # Definindo uma variável para armazenar o índice que representa o caractere que representa a imagem
  classes = np.argmax(pred, axis=1)
  # Print no nome do animal previsto
  print(animal_names[classes[0]])
  # Plote a imagem do animal
  plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
  # Desliga o eixo de plotagem
  plt.axis('off')

# %% [markdown]
# ## Testando o modelo!!🐱🐶
#
# Chegou o momento de validarmos se essa rede neural consegue realmente identificar novas imagens de cachorros e gatos.

# %%
guess_animal('/content/drive/My Drive/teste imagens caes e gatos/cat.10014.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# gatinhos

# %%
guess_animal('/content/drive/My Drive/teste imagens caes e gatos/cat.9338.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# cachorrinhos

# %%
guess_animal('/content/drive/My Drive/teste imagens caes e gatos/dog.9800.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# gatinhos

# %%
guess_animal('/content/drive/My Drive/teste imagens caes e gatos/dog.7394.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# cachorrinhos

# %%
guess_animal('/content/drive/My Drive/teste imagens caes e gatos/cat.10862.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# cachorrinhos

# %%
guess_animal('/content/drive/My Drive/teste imagens caes e gatos/dog.4538.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# cachorrinhos
